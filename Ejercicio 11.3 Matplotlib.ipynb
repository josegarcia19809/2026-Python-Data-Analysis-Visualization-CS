# %% [markdown]
# # Ejercicio de Matplotlib

# %% [markdown]
# ## Parte 3
#
# Recrea la gráfica de pastel que se muestra a continuación:
#
# * He proporcionado listas con los números reales, las etiquetas y los colores.
# * La figura debe ser de 8x8.
# * ¡Observa los porcentajes en cada porción!
# * Dos porciones están ligeramente separadas (exploded).
#
#
# ![Part3.png](attachment:Part3.png)

# %%
# Use these lists to generate the chart!
labels = [
    "Building Construction", 
    "Deferred Maintenance",
    "General Contractor Fees",
    "Owner Costs",
    "Site Construction"
]
costs = [
    47945975,
    3753584,
    7340612,
    18247137,
    5766685
]
colors = ["#355070", "#6d597a", "#b56576", "#e56b6f", "#eaac8b"]

# %%
# ¡Haz tu trabajo aquí!
