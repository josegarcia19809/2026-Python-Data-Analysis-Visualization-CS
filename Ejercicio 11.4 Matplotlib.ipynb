# %% [markdown]
# # Ejercicio de Matplotlib

# %% [markdown]
# ## Parte 4
#
# Recrea la figura que aparece en esta imagen:
#
# * Usa el conjunto de datos `kc_house_data.csv` (impórtalo con Pandas)
# * La figura debe ser de 10x4
#
# ![Part4.png](attachment:Part4.png)

# %%
# ¡Haz tu trabajo aquí!

# %%
import pandas as pd

# %%
houses = pd.read_csv("data/kc_house_data.csv")

# %% [markdown]
# ### Recuerda convertir la columna `date` al formato correcto
