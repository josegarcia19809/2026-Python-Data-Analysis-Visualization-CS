# %% [markdown]
# # Visualizations With Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## load_dataset()
# Seaborn comes with a handy way to quickly get some datasets to play with, but please note this is NOT the normal way of loading a CSV file.  Usually we'd use pandas.read_csv() as we've seen so far.

# %% [markdown]
# ### 🍽️📊 Cargar el conjunto de datos `tips`
#
# Esta operación utiliza la función `load_dataset()` de Seaborn para cargar el conjunto de datos llamado **`tips`**.
#
# Este conjunto de datos contiene información sobre cuentas y propinas registradas en un restaurante, incluyendo variables como:
#
# - 💵 `total_bill`: importe total de la cuenta.
# - 💰 `tip`: propina otorgada.
# - 🚻 `sex`: sexo del cliente.
# - 🚬 `smoker`: indica si el cliente es fumador.
# - 📅 `day`: día de la semana.
# - ⏰ `time`: momento del día (almuerzo o cena).
# - 👥 `size`: tamaño del grupo.
#
# El DataFrame resultante se almacena en la variable `tips` y puede utilizarse para practicar análisis de datos, visualización y técnicas de manipulación con Pandas y Seaborn. 📈🍴

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# ## Seaborn Scatterplots

# %% [markdown]
# ### 🎨 Configurar el estilo visual de Seaborn
#
# Esta operación establece el tema visual predeterminado de Seaborn para los gráficos que se generen posteriormente.
#
# Al aplicar el tema, Seaborn ajusta automáticamente aspectos como:
#
# - 🎨 Estilo general del gráfico.
# - 📝 Tipografía y tamaño de texto.
# - 📏 Líneas de cuadrícula.
# - 📊 Apariencia de ejes y etiquetas.
#
# El objetivo es mejorar la legibilidad y la presentación de las visualizaciones sin necesidad de realizar configuraciones adicionales en cada gráfico. 📈✨

# %%
sns.set_theme()

# %% [markdown]
# ### 📈 Visualizar la relación entre el total de la cuenta y la propina
#
# Esta operación crea un **gráfico de dispersión** (*scatter plot*) utilizando el conjunto de datos `tips`.
#
# En el gráfico:
#
# - 💵 `total_bill` se representa en el eje horizontal (X).
# - 💰 `tip` se representa en el eje vertical (Y).
#
# Cada punto corresponde a una cuenta registrada en el restaurante. La posición del punto muestra el importe total de la cuenta y la propina asociada.
#
# Este tipo de gráfico es útil para identificar patrones, tendencias o posibles relaciones entre dos variables numéricas. Por ejemplo, permite observar si las propinas tienden a aumentar conforme aumenta el valor de la cuenta. 🍽️📊

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 📈 Crear un gráfico de dispersión con Pandas
#
# Esta operación genera un **gráfico de dispersión** (*scatter plot*) utilizando el método `plot()` de Pandas.
#
# Se utiliza la columna `total_bill` como eje horizontal (X) y la columna `tip` como eje vertical (Y).
#
# Cada punto representa una observación del conjunto de datos, mostrando la relación entre el importe total de una cuenta y la propina recibida.
#
# Este gráfico permite visualizar posibles tendencias, correlaciones o patrones entre ambas variables, ayudando a responder preguntas como si las propinas aumentan cuando aumenta el valor de la cuenta. 🍽️💵📊

# %%
tips.plot(kind="scatter", x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 🚬 `hue="smoker"`
#
# El parámetro `hue` utiliza una variable categórica para diferenciar los datos mediante colores.
#
# En este caso, los puntos del gráfico se colorean según el valor de la columna `smoker`, permitiendo distinguir visualmente entre clientes fumadores y no fumadores.

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 🚻 `hue="sex"`
#
# El parámetro `hue` colorea los puntos según los valores de la columna `sex`.
#
# Esto permite distinguir visualmente los registros correspondientes a hombres y mujeres dentro del mismo gráfico.

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 📅 `hue="day"`
#
# El parámetro `hue` colorea los puntos según los valores de la columna `day`.
#
# Cada día de la semana presente en el conjunto de datos se representa con un color diferente, lo que facilita comparar visualmente el comportamiento de las cuentas y propinas entre distintos días.

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
#  🚻 `hue="sex"`
#
# Colorea los puntos según el sexo de los clientes, permitiendo diferenciar visualmente hombres y mujeres.
#
#
#  ⏰ `style="time"`
#
# El parámetro `style` utiliza diferentes formas o marcadores para representar los valores de la columna `time`.
#
# Esto permite distinguir visualmente los registros correspondientes al almuerzo (`Lunch`) y la cena (`Dinner`) mediante símbolos distintos, además de los colores definidos por `hue`.

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", style="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 🚻 `style="sex"`
#
# El parámetro `style` utiliza diferentes formas o marcadores según los valores de la columna `sex`.
#
# Como también se está usando `hue="sex"`, la misma variable se representa mediante dos características visuales:
#
# - 🎨 Color de los puntos.
# - 🔷 Forma de los marcadores.
#
# Esto hace más fácil distinguir los grupos, especialmente cuando el gráfico se imprime en blanco y negro o cuando los colores son difíciles de diferenciar.

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", style="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 🔍 `size="size"`
#
# El parámetro `size` modifica el tamaño de los puntos según los valores de la columna `size`.
#
# Los registros con valores más altos en esta columna se muestran con marcadores más grandes, mientras que los valores más pequeños se representan con marcadores más pequeños.
#
# Esto permite incorporar una tercera variable numérica al gráfico además de las variables representadas en los ejes X e Y. 📊

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", size="size")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 🚻 `hue="sex"`
#
# Colorea los puntos según el sexo de los clientes, permitiendo distinguir visualmente cada categoría.
#
# ### 🔍 `size="size"`
#
# Ajusta el tamaño de los puntos de acuerdo con los valores de la columna `size`.
#
# De esta forma, el gráfico representa cuatro variables al mismo tiempo:
#
# - 📍 Posición horizontal: `total_bill`
# - 📍 Posición vertical: `tip`
# - 🎨 Color: `sex`
# - 🔵 Tamaño del punto: `size`

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", size="size", hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Seaborn Line Plots

# %% [markdown]
# ### ✈️ Cargar el conjunto de datos `flights`
#
# Carga el conjunto de datos `flights` de Seaborn y lo almacena en la variable `flights`.
#
# Este conjunto contiene información sobre el número de pasajeros aéreos por mes y por año, siendo útil para practicar análisis de series temporales y gráficos de líneas. 📈

# %%
flights = sns.load_dataset("flights")

# %% [markdown]
# ### 📈 Gráfico de líneas
#
# Representa la evolución de la variable `passengers` a lo largo de los años.
#
# Como existen varios registros para cada año (uno por cada mes), Seaborn calcula automáticamente la **media** de pasajeros para cada año antes de dibujar la línea.

# %%
sns.lineplot(data=flights, x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ### 📊 Agrupar y graficar
#
# Agrupa los registros por año y calcula el promedio de pasajeros para cada grupo.
#
# Posteriormente, el método `plot()` genera un gráfico de líneas utilizando esos promedios anuales.

# %%
flights.groupby("year")["passengers"].mean().plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ### ➕ `estimator="sum"`
#
# Indica que los valores de pasajeros deben agregarse mediante una **suma** para cada año.
#
# En lugar de mostrar el promedio anual, la línea representará el total de pasajeros registrados en cada año.

# %%
sns.lineplot(data=flights, x="year", y="passengers", estimator="sum")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ### 🎨 `hue="month"`
#
# Crea una línea independiente para cada mes utilizando colores diferentes.
#
# Esto permite comparar cómo cambia el número de pasajeros de cada mes a lo largo de los años.

# %%
sns.lineplot(data=flights, x="year", y="passengers", hue="month")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ### 📅 `parse_dates=["pickup", "dropoff"]`
#
# Convierte automáticamente las columnas `pickup` y `dropoff` al tipo fecha y hora (`datetime`).
#
# Esto permite realizar operaciones relacionadas con fechas, como extraer el año, mes, día, hora o calcular diferencias de tiempo.

# %%
trips= sns.load_dataset("taxis", parse_dates=["pickup", "dropoff"])

# %% [markdown]
# ### 🕒 `.dt.hour`
#
# Extrae la hora de cada valor de la columna `pickup` y la almacena en una nueva columna llamada `hour`.
#
# Los valores resultantes estarán en un rango de **0 a 23**, representando las horas del día.

# %%
trips["hour"] = trips["pickup"].dt.hour

# %%
trips
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %% [markdown]
# ### 🎨 `hue="payment"`
#
# Crea una línea independiente para cada método de pago utilizando colores diferentes.
#
# ### 🔷 `style="color"`
#
# Utiliza diferentes estilos de línea según los valores de la columna `color`.
#
# ### 🚫 `errorbar=None`
#
# Oculta las bandas de error que Seaborn muestra por defecto alrededor de las líneas, dejando visible únicamente la línea principal.

# %%
sns.lineplot(data=trips, x="hour", y="total", hue="payment", style="color", errorbar=None)
# Out:
# <Axes: xlabel='hour', ylabel='total'>

# %% [markdown]
# ## The Figure-Level Relplot( ) Method

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### 🔍 `kind="scatter"`
#
# Indica que se debe crear un gráfico de dispersión (*scatter plot*).
#
# ### 🚻 `col="sex"`
#
# Divide la visualización en varias columnas, creando un gráfico independiente para cada valor de la columna `sex`.
#
# Esto permite comparar los datos de hombres y mujeres en gráficos separados.

# %%
sns.relplot(data=tips, x="total_bill", y="tip", kind="scatter", col="sex")

# %% [markdown]
# ### 🚬 `hue="smoker"`
#
# Colorea los puntos según si el cliente es fumador o no.
#
# ### 🚻 `col="sex"`
#
# Crea una columna de gráficos para cada valor de la columna `sex`, permitiendo comparar hombres y mujeres por separado.

# %%
sns.relplot(data=tips, x="total_bill", y="tip", kind="scatter", hue="smoker", col="sex")

# %% [markdown]
# ### 🚬 `hue="smoker"`
#
# Colorea los puntos según si el cliente es fumador o no.
#
# ### 🚻 `col="sex"`
#
# Crea una columna de gráficos para cada valor de la columna `sex`.
#
# ### ⏰ `row="time"`
#
# Crea una fila de gráficos para cada valor de la columna `time`.
#
# El resultado es una cuadrícula de gráficos donde cada combinación de sexo y momento del día (almuerzo o cena) se muestra en un panel independiente, facilitando las comparaciones entre grupos.

# %%
sns.relplot(data=tips, x="total_bill", y="tip", kind="scatter", hue="smoker", col="sex", row="time")

# %% [markdown]
# ### 📈 `kind="line"`
#
# Indica que se deben crear gráficos de líneas.
#
# ### 🏙️ `col="pickup_borough"`
#
# Genera una columna de gráficos para cada distrito de recogida (*borough*).
#
# Cada distrito se muestra en un panel independiente.
#
# ### 🎨 `hue="payment"`
#
# Dibuja una línea diferente para cada método de pago utilizando colores distintos dentro de cada gráfico.

# %%
sns.relplot(data=trips, x="hour", y="total", kind="line", col="pickup_borough", hue="payment")

# %% [markdown]
# ### 🏙️ `col="pickup_borough"`
#
# Crea una columna de gráficos para cada distrito de recogida (*pickup borough*).
#
# ### 📍 `row="dropoff_borough"`
#
# Crea una fila de gráficos para cada distrito de destino (*dropoff borough*).
#
# ### 🎨 `hue="payment"`
#
# Dibuja una línea diferente para cada método de pago utilizando colores distintos dentro de cada gráfico.
#
# El resultado es una cuadrícula de gráficos donde cada panel representa una combinación específica de distrito de recogida y distrito de destino.

# %%
sns.relplot(
    data=trips, 
    x="hour",
    y="total", 
    kind="line", 
    col="pickup_borough", 
    hue="payment", 
    row="dropoff_borough"
)

# %% [markdown]
# ## Changing Plot Sizes

# %% [markdown]
# ### 📏 `figsize=(8,5)`
#
# Define el tamaño de la figura.
#
# - **8** representa el ancho.
# - **5** representa el alto.
#
# Las dimensiones se expresan en pulgadas (*inches*), permitiendo controlar el espacio disponible para el gráfico.

# %%
plt.figure(figsize=(8,5))
sns.lineplot(data=flights, x="year", y="passengers", hue="month")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ### 🚬 `hue="smoker"`
#
# Colorea los puntos según si el cliente es fumador o no.
#
# ### 📅 `col="day"`
#
# Crea una columna de gráficos para cada día.
#
# ### 🚻 `row="sex"`
#
# Crea una fila de gráficos para cada sexo.
#
# ### 📏 `height=2`
#
# Define la altura de cada gráfico individual en pulgadas.
#
# ### ↔️ `aspect=2`
#
# Define la relación entre ancho y alto de cada gráfico.
#
# Un valor de `2` indica que cada gráfico tendrá un ancho aproximadamente dos veces mayor que su altura.

# %%
sns.relplot(
    data=tips, 
    x="total_bill", 
    y="tip", 
    kind="scatter", 
    hue="smoker", 
    col="day",
    row="sex",
    height=2,
    aspect=2
)

# %% [markdown]
# ## Seaborn Histograms

# %% [markdown]
# ### 📊 Histograma
#
# Muestra la distribución de los valores de la columna `tip`.
#
# Los datos se agrupan en intervalos (*bins*) y la altura de cada barra representa la cantidad de observaciones que se encuentran dentro de cada rango de propinas.

# %%
sns.histplot(data=tips, x="tip")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### ⏰ `hue="time"`
#
# Colorea las barras del histograma según los valores de la columna `time`.
#
# Esto permite comparar la distribución de las propinas entre los registros de almuerzo (`Lunch`) y cena (`Dinner`) dentro del mismo gráfico.

# %%
sns.histplot(data=tips, x="tip", hue="time")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### 🚬 `hue="smoker"`
#
# Diferencia las observaciones según si el cliente es fumador o no, utilizando colores distintos.
#
# ### 📚 `multiple="stack"`
#
# Apila las barras correspondientes a cada categoría una encima de otra.
#
# Esto permite visualizar tanto el total de observaciones en cada intervalo como la contribución de cada grupo dentro de la barra.

# %%
sns.histplot(data=tips, x="tip", hue="smoker", multiple="stack")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### 🚬 `hue="smoker"`
#
# Diferencia las observaciones según si el cliente es fumador o no mediante colores distintos.
#
# ### ↔️ `multiple="dodge"`
#
# Muestra las barras de cada categoría una al lado de la otra dentro de cada intervalo.
#
# Esto facilita comparar directamente las frecuencias de cada grupo en cada rango de valores.

# %%
sns.histplot(data=tips, x="tip", hue="smoker", multiple="dodge")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### 📏 `binwidth=500`
#
# Define el ancho de cada intervalo (*bin*) del histograma.
#
# En este caso, los datos se agrupan en rangos de **500 gramos**, por ejemplo:
#
# - 3000–3500
# - 3500–4000
# - 4000–4500
#
# Esto permite controlar el nivel de detalle con el que se muestra la distribución de los datos.

# %%
sns.histplot(data=penguins, x="body_mass_g", binwidth=500)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# ### 📦 `bins=20`
#
# Indica que el histograma debe dividir los datos en **20 intervalos** (*bins*).
#
# Un mayor número de intervalos muestra más detalle en la distribución, mientras que un número menor produce una visualización más agrupada.

# %%
sns.histplot(data=penguins, x="body_mass_g", bins=20)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# ### 🐧 `hue="species"`
#
# Diferencia los datos según la especie de pingüino utilizando colores distintos.
#
# ### 📚 `multiple="stack"`
#
# Apila las barras de cada especie dentro de cada intervalo.
#
# Esto permite observar tanto la frecuencia total como la contribución de cada especie en cada rango de masa corporal.

# %%
sns.histplot(data=penguins, x="body_mass_g", bins=20, hue="species", multiple="stack")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# ### 🐧 `hue="species"`
#
# Diferencia los datos según la especie de pingüino utilizando colores distintos.
#
# ### 📚 `multiple="stack"`
#
# Apila las categorías dentro de cada intervalo del histograma.
#
# ### 📐 `element="step"`
#
# Dibuja los intervalos utilizando contornos escalonados en lugar de barras rellenas.
#
# Esto permite visualizar con mayor claridad los límites de cada intervalo y las contribuciones de cada categoría.

# %%
sns.histplot(data=penguins, x="body_mass_g", bins=20, hue="species", multiple="stack", element="step")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# ### 📈 `kde=True`
#
# Agrega una curva de **estimación de densidad kernel (KDE)** sobre el histograma.
#
# Esta curva proporciona una representación suavizada de la distribución de los datos, ayudando a identificar la forma general, los picos y la concentración de valores.

# %%
sns.histplot(data=tips, x="tip", kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### 🎨 `palette="muted"`
#
# Utiliza la paleta de colores **"muted"** de Seaborn para representar las distintas especies.
#
# ### 📈 `kde=True`
#
# Agrega una curva suavizada de densidad sobre el histograma para visualizar mejor la distribución de los datos.
#
# ### 🖥️ `dpi=200`
#
# Aumenta la resolución de la figura a 200 puntos por pulgada, produciendo una imagen más nítida.
#
# ### 🏷️ `plt.title("Penguin Body Mass")`
#
# Añade un título al gráfico con el texto **"Penguin Body Mass"**.

# %%
sns.set_theme()
plt.figure(dpi=200)
sns.histplot(
    data=penguins, 
    x="body_mass_g", 
    hue="species", 
    multiple="stack", 
    palette="muted",
    bins=20,
    kde=True
)
plt.title("Penguin Body Mass")
# Out:
# Text(0.5, 1.0, 'Penguin Body Mass')

# %% [markdown]
# ## Seaborn KDE Plots

# %% [markdown]
# ### 📈 Gráfico KDE
#
# Crea un gráfico de **estimación de densidad kernel (KDE)** para la columna `body_mass_g`.
#
# En lugar de mostrar frecuencias mediante barras, representa una curva suavizada que describe cómo se distribuyen los valores de masa corporal en el conjunto de datos.

# %%
sns.kdeplot(data=penguins, x="body_mass_g")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %% [markdown]
# ### 🐧 `hue="species"`
#
# Dibuja una curva de densidad independiente para cada especie de pingüino utilizando colores diferentes.
#
# Esto permite comparar visualmente cómo se distribuye la masa corporal entre las distintas especies.

# %%
sns.kdeplot(data=penguins, x="body_mass_g", hue="species")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %% [markdown]
# ### 🐧 `hue="species"`
#
# Dibuja una curva de densidad independiente para cada especie utilizando colores diferentes.
#
# ### 🎛️ `bw_adjust=0.4`
#
# Ajusta el nivel de suavizado de las curvas KDE.
#
# Valores menores que `1` generan curvas más detalladas y sensibles a las variaciones de los datos, mientras que valores mayores producen curvas más suaves.

# %%
sns.kdeplot(data=penguins, x="body_mass_g", hue="species", bw_adjust=0.4)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %% [markdown]
# ### 🐧 `hue="species"`
#
# Dibuja una curva de densidad independiente para cada especie utilizando colores diferentes.
#
# ### 📚 `multiple="stack"`
#
# Apila las curvas de densidad una sobre otra en lugar de superponerlas.
#
# Esto facilita observar la contribución de cada categoría a la distribución total.

# %%
sns.kdeplot(data=penguins, x="body_mass_g", hue="species", multiple="stack")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %% [markdown]
# ## Gráficos de distribución bivariada

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# ### 📊 Histograma
#
# Muestra la distribución de los valores de la columna `flipper_length_mm`.
#
# Los datos se agrupan en intervalos y la altura de cada barra representa la cantidad de pingüinos cuya longitud de aleta se encuentra dentro de cada rango.

# %%
sns.histplot(data=penguins, x="flipper_length_mm")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# ### 📊 Histograma
#
# Muestra la distribución de los valores de la columna `body_mass_g`.
#
# Los datos se agrupan en intervalos y la altura de cada barra indica cuántos pingüinos tienen una masa corporal dentro de cada rango.

# %%
sns.histplot(data=penguins, x="body_mass_g")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# ### 📊 Histograma bidimensional
#
# Al especificar las variables `x` e `y`, Seaborn crea un histograma en dos dimensiones.
#
# En lugar de contar valores en un único eje, el gráfico divide ambas variables en intervalos y muestra cuántas observaciones existen en cada combinación de rangos.
#
# Esto permite analizar la relación entre la masa corporal (`body_mass_g`) y la longitud de la aleta (`flipper_length_mm`) mediante zonas con mayor o menor concentración de datos.

# %%
sns.histplot(data=penguins, x="body_mass_g", y="flipper_length_mm")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %% [markdown]
# ### 📈 KDE bidimensional
#
# Al especificar las variables `x` e `y`, Seaborn genera una **estimación de densidad kernel en dos dimensiones**.
#
# El gráfico utiliza curvas de nivel para representar las zonas donde existe una mayor concentración de observaciones.
#
# Esto permite visualizar la relación entre `body_mass_g` y `flipper_length_mm`, identificando regiones con alta o baja densidad de datos.

# %%
sns.kdeplot(data=penguins, x="body_mass_g", y="flipper_length_mm")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %% [markdown]
# ### 🐧 `hue="species"`
#
# Dibuja un conjunto de curvas de densidad para cada especie utilizando colores diferentes.
#
# Esto permite comparar cómo se distribuyen conjuntamente la longitud del pico (`bill_length_mm`) y la longitud de la aleta (`flipper_length_mm`) entre las distintas especies.

# %%
sns.kdeplot(data=penguins, x="bill_length_mm", y="flipper_length_mm", hue="species")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# ### 🐧 `hue="species"`
#
# Diferencia las observaciones según la especie utilizando colores distintos.
#
# En un histograma bidimensional, esto permite visualizar cómo se distribuyen conjuntamente la longitud del pico (`bill_length_mm`) y la longitud de la aleta (`flipper_length_mm`) para cada especie.

# %%
sns.histplot(data=penguins, x="bill_length_mm", y="flipper_length_mm", hue="species")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# ## Seaborn Rugplots

# %% [markdown]
# ### 📏 `height=0.2`
#
# Define la altura de las marcas (*rugs*) que aparecen sobre el eje.
#
# Las marcas representan observaciones individuales, y este parámetro controla qué tan largas se dibujan en relación con el tamaño del gráfico.

# %%
sns.rugplot(data=tips, x="tip", height=0.2)
# Out:
# <Axes: xlabel='tip'>

# %% [markdown]
# ### ↕️ `y="tip"`
#
# Dibuja las marcas (*rugs*) sobre el eje vertical utilizando los valores de la columna `tip`.
#
# ### 📏 `height=0.2`
#
# Define la longitud de las marcas en relación con el tamaño del gráfico.

# %%
sns.rugplot(data=tips, y="tip", height=0.2)
# Out:
# <Axes: ylabel='tip'>

# %% [markdown]
# ### 📈 `sns.kdeplot(...)`
#
# Genera una curva de densidad suavizada para mostrar la distribución de los valores de `total_bill`.
#
# ### 📏 `height=0.07`
#
# Hace que las marcas del gráfico *rug* sean más cortas, ocupando aproximadamente el 7% de la altura del gráfico.

# %%
sns.kdeplot(data=tips, x="total_bill")
sns.rugplot(data=tips, x="total_bill", height=0.07)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### ↔️ `x="total_bill"`
#
# Dibuja marcas (*rugs*) correspondientes a los valores de la columna `total_bill` sobre el eje horizontal.
#
# ### ↕️ `y="tip"`
#
# Dibuja marcas (*rugs*) correspondientes a los valores de la columna `tip` sobre el eje vertical.
#
# Al utilizar ambos parámetros, cada observación queda representada por pequeñas marcas en los dos ejes, ayudando a visualizar la distribución exacta de los datos junto al gráfico de dispersión.

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
sns.rugplot(data=tips,x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 🔹 `s=5`
#
# Controla el tamaño de los puntos del gráfico de dispersión.
#
# Un valor de `5` genera marcadores muy pequeños, lo cual es útil cuando existen miles de observaciones y se desea evitar el exceso de superposición.
#
# ### 📏 `lw=1`
#
# Define el grosor (*line width*) de las marcas del gráfico *rug*.
#
# ### 🌫️ `alpha=0.005`
#
# Controla la transparencia de las marcas.
#
# Un valor muy pequeño como `0.005` hace que cada marca sea casi invisible de forma individual, pero las zonas con muchas observaciones se vuelven más visibles debido a la acumulación de marcas.
#
# Esta técnica ayuda a identificar regiones de alta densidad cuando se trabaja con conjuntos de datos grandes.

# %%
diamonds = sns.load_dataset("diamonds")
sns.scatterplot(data=diamonds, x="carat", y="price", s=5)
sns.rugplot(data=diamonds, x="carat", y="price", lw=1, alpha=.005)
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %% [markdown]
# ## The Figure-Level displot( ) Method

# %% [markdown]
# ### 📊 `kind="hist"`
#
# Indica que se debe crear un histograma.
#
# ### 📏 `height=3`
#
# Define la altura del gráfico en pulgadas.
#
# ### ↔️ `aspect=2`
#
# Define la relación entre ancho y alto.
#
# Un valor de `2` hace que el gráfico sea aproximadamente dos veces más ancho que alto.

# %%
sns.displot(kind="hist", data=penguins, x="body_mass_g", height=3, aspect=2)

# %% [markdown]
# ### 🚻 `hue="sex"`
#
# Diferencia los datos según el sexo utilizando colores distintos.
#
# ### 🐧 `col="species"`
#
# Crea un histograma independiente para cada especie de pingüino, mostrándolos en columnas separadas.

# %%
sns.displot(
    kind="hist", 
    data=penguins, 
    hue="sex",
    x="body_mass_g", 
    col="species"
)

# %% [markdown]
# ### 📈 `kind="kde"`
#
# Indica que se debe crear un gráfico de densidad KDE en lugar de un histograma.
#
# ### ⏰ `col="time"`
#
# Genera un gráfico independiente para cada valor de la columna `time`.
#
# ### 📏 `rug=True`
#
# Añade marcas (*rug plots*) sobre el eje para mostrar la posición exacta de cada observación utilizada para construir las curvas de densidad.

# %%
sns.displot(data=tips, kind="kde", x="tip", col="time", rug=True)

# %% [markdown]
# ### 📈 `kind="kde"`
#
# Indica que se debe crear un gráfico de densidad KDE.
#
# ### ↔️ `y="tip"`
#
# Al especificar una variable en `y`, Seaborn genera una **KDE bidimensional**, mostrando la densidad conjunta de ambas variables mediante curvas de nivel.
#
# ### 📏 `rug=True`
#
# Añade marcas (*rug plots*) sobre los ejes para indicar la posición exacta de las observaciones en los datos.

# %%
sns.displot(data=tips, kind="kde", x="total_bill", y="tip", rug=True)

# %% [markdown]
# ## Seaborn Countplots

# %% [markdown]
# ### 📊 Gráfico de conteo
#
# Muestra la cantidad de observaciones que existen para cada categoría de la columna `species`.
#
# La altura de cada barra representa el número de registros pertenecientes a cada especie de pingüino.

# %%
sns.countplot(data=penguins, x="species")
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.countplot(data=penguins, x="species", hue="sex")
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
titanic = pd.read_csv("data/titanic.csv")

# %%
sns.countplot(data=titanic, x="pclass", hue="sex")
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(data=titanic, y="pclass", hue="sex")
# Out:
# <Axes: xlabel='count', ylabel='pclass'>

# %% [markdown]
# ## Seaborn Stripplot & Swarmplot

# %% [markdown]
# ### 🏙️ `x="pickup_borough"`
#
# Utiliza una variable categórica en el eje horizontal, agrupando las observaciones según el distrito de recogida.
#
# ### 📏 `y="distance"`
#
# Representa la distancia del viaje en el eje vertical.
#
# Cada punto corresponde a un viaje individual, permitiendo observar cómo se distribuyen las distancias dentro de cada distrito de recogida.

# %%
sns.scatterplot(data=trips, x="pickup_borough", y="distance")
# Out:
# <Axes: xlabel='pickup_borough', ylabel='distance'>

# %% [markdown]
# ### 📍 `sns.stripplot(...)`
#
# Crea un **strip plot**, donde cada observación se muestra como un punto individual.
#
# Es especialmente útil para visualizar la distribución completa de los datos cuando el eje X contiene categorías.
#
# ### 🖥️ `dpi=100`
#
# Establece la resolución de la figura en 100 puntos por pulgada.
#
# ### 🏷️ `plt.title("Taxi Trip Distance By Burough")`
#
# Añade un título al gráfico para describir su contenido.

# %%
plt.figure(dpi=100)
sns.stripplot(data=trips, x="pickup_borough", y="distance")
plt.title("Taxi Trip Distance By Burough")
# Out:
# Text(0.5, 1.0, 'Taxi Trip Distance By Burough')

# %% [markdown]
# ### 🔝 `nlargest(600, "total")`
#
# Selecciona las **600 filas con los valores más altos** de la columna `total`.
#
# El resultado se almacena en `trips_sample`, creando un nuevo DataFrame que contiene únicamente los viajes con los importes más elevados.

# %%
trips_sample = trips.nlargest(600, "total")

# %% [markdown]
# ### 🐝 `sns.swarmplot(...)`
#
# Crea un **swarm plot**, donde cada observación se representa como un punto individual.
#
# A diferencia de un `stripplot`, los puntos se acomodan automáticamente para evitar superposiciones, facilitando la visualización de la densidad y distribución de los datos.
#
# ### 📏 `figsize=(12,5)`
#
# Define el tamaño de la figura:
#
# - **12** pulgadas de ancho.
# - **5** pulgadas de alto.

# %%
plt.figure(figsize=(12,5))
sns.swarmplot(data=trips_sample, x="pickup_borough", y="distance")
# Out:
# <Axes: xlabel='pickup_borough', ylabel='distance'>

# %% [markdown]
# ### 📏 `figsize=(12,5)`
#
# Define el tamaño de la figura:
#
# - **12** pulgadas de ancho.
# - **5** pulgadas de alto.
#
# ### 📍 `sns.stripplot(...)`
#
# Muestra cada viaje como un punto individual, permitiendo observar la distribución de las distancias dentro de cada distrito de recogida.
#
# ### 🏷️ `plt.title("Taxi Trips By Borough")`
#
# Añade el título **"Taxi Trips By Borough"** al gráfico.

# %%
plt.figure(figsize=(12,5))
sns.stripplot(data=trips_sample, x="pickup_borough", y="distance")
plt.title("Taxi Trips By Borough")
# Out:
# Text(0.5, 1.0, 'Taxi Trips By Borough')

# %%
titanic = sns.load_dataset("titanic")

# %% [markdown]
# ### 🚻 `hue="sex"`
#
# Diferencia las observaciones según el sexo utilizando colores distintos.
#
# En el gráfico, los pasajeros de cada sexo se muestran con colores diferentes dentro de cada clase (`pclass`), facilitando la comparación de las edades entre ambos grupos.

# %%
plt.figure(figsize=(12,5))

sns.swarmplot(data=titanic, x="pclass", y="age", hue="sex")
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %% [markdown]
# ## Seaborn Boxplots

# %% [markdown]
# ### 📦 Gráfico de caja (*Box Plot*)
#
# Muestra la distribución de los valores de la columna `age` mediante un resumen estadístico.
#
# El gráfico permite identificar:
#
# - 📍 La mediana (valor central).
# - 📦 El rango intercuartílico (50% central de los datos).
# - 📏 La dispersión de los valores.
# - ⚠️ Posibles valores atípicos (*outliers*).
#
# Es una herramienta útil para analizar rápidamente la distribución y variabilidad de las edades.

# %%
sns.boxplot(data=titanic, x="age")
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# ### 🏙️ `x="pickup_borough"`
#
# Agrupa los datos según el distrito de recogida.
#
# ### 💵 `y="total"`
#
# Utiliza el importe total del viaje para construir las distribuciones.
#
# Cada categoría de `pickup_borough` tendrá su propio diagrama de caja, permitiendo comparar medianas, dispersión y posibles valores atípicos entre los distintos distritos.

# %%
sns.boxplot(data=trips, x="pickup_borough", y="total")
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %% [markdown]
# ### 📏 `whis=2.5`
#
# Controla la longitud de los bigotes (*whiskers*) del diagrama de caja.
#
# Un valor de `2.5` extiende los bigotes más allá del valor predeterminado, haciendo que menos observaciones sean consideradas valores atípicos (*outliers*).
#
# ### 🔹 `fliersize=2`
#
# Define el tamaño de los puntos que representan los valores atípicos.
#
# Un valor de `2` genera marcadores pequeños para los *outliers*.

# %%
sns.boxplot(data=trips, x="pickup_borough", y="total", whis=2.5, fliersize=2)
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %% [markdown]
# ### 🚻 `hue="sex"`
#
# Crea diagramas de caja separados para cada sexo dentro de cada clase de pasajero (`pclass`), utilizando colores diferentes.
#
# ### 🔹 `fliersize=5`
#
# Define el tamaño de los puntos que representan los valores atípicos (*outliers*).
#
# Un valor de `5` hace que estos puntos sean más visibles en el gráfico.

# %%
sns.boxplot(data=titanic, x="pclass", y="age", hue="sex", fliersize=5)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %% [markdown]
# ### 🐝 `sns.swarmplot(...)`
#
# Superpone un **swarm plot** sobre el diagrama de caja para mostrar cada observación individual.
#
# Esto permite visualizar simultáneamente el resumen estadístico del box plot y los datos reales.
#
# ### 🎨 `color="0.3"`
#
# Utiliza un tono de gris oscuro para todos los puntos del swarm plot.
#
# El valor `0.3` representa un nivel de intensidad de gris, donde `0` es negro y `1` es blanco.

# %%
sns.boxplot(data=penguins, x="species", y="body_mass_g")
sns.swarmplot(data=penguins, x="species", y="body_mass_g", color="0.3")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# ## Seaborn Boxenplots

# %%
sns.boxplot(data=trips, x="pickup_borough", y="total")
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %% [markdown]
# ### 📦 `sns.boxenplot(...)`
#
# Crea un **boxen plot** (*letter value plot*), una variante del box plot diseñada para conjuntos de datos grandes.
#
# Muestra con mayor detalle la distribución de los datos, especialmente en las colas de la distribución, permitiendo observar mejor cómo se concentran y dispersan los valores.
#
# ### 📏 `figsize=(10,6)`
#
# Define el tamaño de la figura:
#
# - **10** pulgadas de ancho.
# - **6** pulgadas de alto.

# %%
plt.figure(figsize=(10,6))
sns.boxenplot(data=trips, x="pickup_borough", y="total")
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %% [markdown]
# ## Seaborn Violinplots

# %% [markdown]
# ### 🎻 `sns.violinplot(...)`
#
# Crea un **gráfico de violín**, que combina características de un histograma y un gráfico de densidad KDE.
#
# El ancho del violín representa la concentración de datos en cada valor o rango de valores.
#
# Esto permite visualizar tanto la distribución general como las zonas donde existen más o menos observaciones.
#
# ### 💡 Comparación con `boxplot`
#
# Mientras que un **box plot** resume los datos mediante cuartiles, mediana y valores atípicos, un **violin plot** muestra además la forma completa de la distribución.

# %%
sns.violinplot(data=titanic, x="age")
# sns.boxplot(data=titanic, x="age")
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# ### 🏷️ `x="pclass"`
#
# Crea un gráfico de violín independiente para cada clase de pasajero.
#
# ### 📏 `y="age"`
#
# Utiliza la edad para construir la distribución de cada grupo.
#
# Esto permite comparar visualmente cómo se distribuyen las edades entre las distintas clases de pasajeros.

# %%
sns.violinplot(data=titanic, x="pclass", y="age")
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %% [markdown]
# ### 🚻 `hue="sex"`
#
# Divide cada categoría de `pclass` según el sexo y utiliza colores diferentes para cada grupo.
#
# Esto permite comparar la distribución de edades de hombres y mujeres dentro de cada clase de pasajero.

# %%
sns.violinplot(data=titanic, x="pclass", y="age", hue="sex")
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %% [markdown]
# ### 🚻 `hue="sex"`
#
# Divide los datos según el sexo y utiliza colores diferentes para cada grupo.
#
# ### ✂️ `split=True`
#
# Muestra ambas distribuciones dentro del mismo violín, una a cada lado del eje central.
#
# Esto facilita la comparación directa entre los grupos definidos por `hue`.
#
# ### 🎨 `palette="muted"`
#
# Utiliza la paleta de colores **"muted"**, con tonos más suaves y menos intensos.
#
# ### 📏 `figsize=(10,4)`
#
# Define el tamaño de la figura:
#
# - **10** pulgadas de ancho.
# - **4** pulgadas de alto.

# %%
plt.figure(figsize=(10,4))
sns.violinplot(data=titanic, x="pclass", y="age", hue="sex", split=True, palette="muted")
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %% [markdown]
# ## Seaborn Barplots

# %% [markdown]
# ### 📊 Gráfico de barras
#
# Cuando se utiliza una variable categórica en `x` y una numérica en `y`, `barplot` calcula un valor agregado para cada categoría.
#
# ### 🏙️ `x="pickup_borough"`
#
# Agrupa los datos según el distrito de recogida.
#
# ### 📏 `y="distance"`
#
# Utiliza la distancia de los viajes para calcular la altura de cada barra.
#
# Por defecto, Seaborn muestra la **media** de `distance` para cada distrito.

# %%
sns.barplot(data=trips, x="pickup_borough", y="distance")
# Out:
# <Axes: xlabel='pickup_borough', ylabel='distance'>

# %% [markdown]
# ### 🏙️ `x="pickup_borough"`
#
# Agrupa los datos según el distrito de recogida.
#
# ### 💵 `y="total"`
#
# Utiliza el importe total de los viajes para calcular la altura de cada barra.
#
# Por defecto, Seaborn muestra la **media** de `total` para cada distrito, permitiendo comparar el costo promedio de los viajes entre las distintas categorías.

# %%
sns.barplot(data=trips, x="pickup_borough", y="total")
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %% [markdown]
# ### ➕ `estimator=sum`
#
# Indica que los valores de cada categoría deben agregarse mediante una **suma**.
#
# En lugar de mostrar el promedio de `total` para cada distrito, las barras representarán el importe total acumulado de los viajes en cada `pickup_borough`.

# %%
sns.barplot(data=trips, x="pickup_borough", y="total", estimator=sum)
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %% [markdown]
# ### 📂 `groupby("pickup_borough")`
#
# Agrupa los registros según el distrito de recogida.
#
# ### 💵 `["total"].sum()`
#
# Calcula la suma total de la columna `total` para cada distrito.
#
# ### 📊 `plot(kind="bar")`
#
# Genera un gráfico de barras utilizando los resultados del agrupamiento.
#
# Cada barra representa el importe total acumulado de los viajes para un distrito determinado.

# %%
trips.groupby("pickup_borough")["total"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='pickup_borough'>

# %% [markdown]
# ### 🚕 `hue="color"`
#
# Divide cada categoría de `pickup_borough` según los valores de la columna `color` y utiliza colores distintos para representarlas.
#
# Esto genera varias barras dentro de cada distrito, permitiendo comparar las distancias promedio entre las diferentes categorías de `color`.

# %%
sns.barplot(data=trips, x="pickup_borough", y="distance", hue="color")
# Out:
# <Axes: xlabel='pickup_borough', ylabel='distance'>

# %% [markdown]
# ### ↔️ `y="pickup_borough"`
#
# Al colocar la variable categórica en `y`, las barras se muestran horizontalmente.
#
# ### 🚕 `hue="color"`
#
# Divide cada categoría según los valores de la columna `color`.
#
# ### 📌 `dodge=False`
#
# Evita que las barras de cada categoría se dibujen lado a lado.
#
# En su lugar, las barras se superponen en la misma posición, facilitando la comparación directa entre grupos.

# %%
sns.barplot(data=trips, y="pickup_borough", x="distance", hue="color", dodge=False)
# Out:
# <Axes: xlabel='distance', ylabel='pickup_borough'>

# %% [markdown]
# ### ↔️ `orient="h"`
#
# Indica que el gráfico debe utilizar una orientación horizontal.
#
# Las barras se dibujarán de izquierda a derecha, utilizando el eje X para los valores numéricos y el eje Y para las categorías.

# %%
sns.barplot(data=titanic, y="pclass", x="survived", orient="h")
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %% [markdown]
# ## The Figure-Level catplot( ) Method

# %% [markdown]
# ### 📊 `kind="bar"`
#
# Indica que `catplot` debe generar un gráfico de barras.
#
# `catplot` es una interfaz de alto nivel que permite crear distintos tipos de gráficos categóricos utilizando el parámetro `kind`.
#
# ### 🚻 `x="sex"`
#
# Agrupa los datos según el sexo.
#
# ### ✅ `y="survived"`
#
# Por tratarse de una variable binaria (0 = no sobrevivió, 1 = sobrevivió), la altura de cada barra representa la proporción promedio de supervivencia para cada sexo.

# %%
sns.catplot(data=titanic, x="sex", y="survived", kind="bar")

# %% [markdown]
# ### 🏷️ `col="pclass"`
#
# Crea un gráfico independiente para cada valor de la columna `pclass`.
#
# Esto permite comparar las tasas de supervivencia por sexo dentro de cada clase de pasajero.

# %%
sns.catplot(data=titanic, x="sex", y="survived", kind="bar", col="pclass")

# %% [markdown]
# ### 🚻 `hue="sex"`
#
# Divide cada categoría de `pclass` según el sexo y utiliza colores diferentes para representarlas.
#
# Esto permite comparar las tasas de supervivencia de hombres y mujeres dentro de cada clase de pasajero.

# %%
sns.catplot(data=titanic, x="pclass", y="survived", kind="bar", hue="sex")

# %% [markdown]
# ### 📍 `kind="strip"`
#
# Indica que `catplot` debe generar un **strip plot**.
#
# ### 🚕 `col="color"`
#
# Crea un gráfico independiente para cada valor de la columna `color`.
#
# ### ↔️ `aspect=0.8`
#
# Define la relación entre el ancho y la altura de cada gráfico.
#
# Un valor de `0.8` produce gráficos ligeramente más estrechos que altos.

# %%
sns.catplot(
    data=trips, 
    kind="strip", 
    x="pickup_borough", 
    y="distance", 
    col="color",
    aspect=0.8
)

# %% [markdown]
# ### 🎻 `kind="violin"`
#
# Indica que `catplot` debe generar gráficos de violín.
#
# ### 🚕 `hue="color"`
#
# Divide cada categoría según los valores de la columna `color` y utiliza colores diferentes para representarlas.
#
# ### ✂️ `split=True`
#
# Muestra las distribuciones de las categorías definidas por `hue` dentro del mismo violín, una a cada lado del eje central.
#
# Esto facilita la comparación directa entre ambos grupos dentro de cada distrito.

# %%
sns.catplot(data=trips, kind="violin", x="pickup_borough", y="distance", hue="color", split=True)

# %% [markdown]
# ### 🧑 `x="who"`
#
# Agrupa los datos según la categoría de pasajero (`man`, `woman` o `child`).
#
# ### 🏷️ `col="pclass"`
#
# Crea un gráfico independiente para cada clase de pasajero.
#
# ### 🚫 `errorbar=None`
#
# Oculta las barras de error que Seaborn muestra por defecto sobre cada barra.

# %%
sns.catplot(
    data=titanic, 
    kind="bar",
    x="who",
    y="survived",
    col="pclass",
    errorbar=None,
)
