# %% [markdown]
# # Plotting With Pandas (and matplotlib)

# %% [markdown]
# 📥 **Importamos las bibliotecas necesarias**
#
# Usamos `pandas` para manejar los datos y `matplotlib.pyplot` para graficarlos. 📊

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 🚢 **Cargamos el conjunto de datos del Titanic**
#
# Convertimos la columna `age` a valores numéricos, y los errores se convierten en `NaN` para evitar problemas. 👶👵

# %%
titanic = pd.read_csv("data/titanic.csv")
titanic["age"] = pd.to_numeric(titanic["age"], errors="coerce")

# %% [markdown]
# 🏡 **Cargamos los datos de precios de casas**
#
# Este conjunto contiene información de viviendas en King County, WA. 📈

# %%
houses = pd.read_csv("data/kc_house_data.csv")

# %% [markdown]
# 🛸 **Cargamos datos de avistamientos de OVNIs**
#
# Usamos `parse_dates` para que las columnas de fechas se interpreten como objetos `datetime`. 🌌

# %%
ufos = pd.read_csv("data/nuforc_reports.csv", parse_dates=['date_time', "posted"])

# %% [markdown]
# 👫 **Contamos el número de pasajeros por sexo**
#
# Usamos `value_counts()` para saber cuántos hombres y mujeres viajaban en el Titanic.

# %%
titanic.sex.value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %% [markdown]
# 📊 **Graficamos el número de pasajeros por sexo**
#
# Creamos un gráfico de barras para visualizar cuántos hombres y mujeres había a bordo del Titanic.

# %% [markdown]
# 📊 **Gráfico de barras a partir de conteo de valores**
#
# Visualizamos cuántas veces aparece cada valor categórico.

# %%
titanic.sex.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='sex'>

# %% [markdown]
# 🏠 **Exploramos las casas más grandes**
#
# Ordenamos por el tamaño de vivienda (`sqft_living`) y mostramos las 10 más grandes.

# %%
houses[["sqft_living", "sqft_lot"]].sort_values("sqft_living", ascending=False).head(10)
# Out:
#        sqft_living  sqft_lot
# 12777        13540    307752
# 7252         12050     27600
# 3914         10040     37325
# 9254          9890     31374
# 8092          9640     13068
# 4411          9200     35069
# 14556         8670     64033
# 18302         8020     21738
# 1164          8010     45517
# 1448          8000     23985

# %% [markdown]
# 🏠 **Exploramos las casas más grandes**
#
# Ordenamos por el tamaño de vivienda (`sqft_living`) y mostramos las 10 más grandes.

# %%
houses[["sqft_living", "sqft_lot"]].sort_values("sqft_living", ascending=False).head(10).plot(kind="bar")
# Out:
# <Axes: >

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# ### 📌 Explicación del código
#
# `plt.style.use("fivethirtyeight")`
#
# 🔹 **`plt`**
# Hace referencia a la librería **Matplotlib (pyplot)**, usada para crear gráficas.
#
# 🔹 **`style.use()`**
# Permite aplicar un **estilo visual predefinido** a las gráficas.
#
# 🔹 **`"fivethirtyeight"`**
# Es un estilo inspirado en el sitio de análisis de datos **FiveThirtyEight**, conocido por gráficas limpias y modernas.
#
# 📌 ¿Qué cambia?
#
# - Colores más suaves
# - Fondos grises
# - Líneas más visibles
# - Mejor presentación general
#
# 🔹 **Resultado**
# Todas las gráficas que hagas después tendrán ese estilo automáticamente.
#
# 👉 **En resumen:**
# Aplica un estilo visual moderno a las gráficas de Matplotlib.

# %%
plt.style.use("fivethirtyeight")

# %% [markdown]
# ### 📊 Explicación del código
#
# `titanic.sex.value_counts().plot(kind="bar")`
#
# 🔹 **`titanic.sex`**
# Accede a la columna **`sex`** del DataFrame.
#
# 🔹 **`.value_counts()`**
# Cuenta cuántas veces aparece cada valor (por ejemplo: `male`, `female`).
#
# 🔹 **`.plot(kind="bar")`**
# Crea una **gráfica de barras** con esos conteos.
#
# 📌 ¿Qué muestra la gráfica?
#
# - Eje X → categorías (`male`, `female`)
# - Eje Y → cantidad de pasajeros
# - Cada barra representa cuántos hay de cada sexo
#
# 👉 **En resumen:**
# Cuenta cuántos hombres y mujeres hay en el Titanic y lo muestra en una gráfica de barras.

# %%
titanic.sex.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='sex'>

# %% [markdown]
# ### 📊 Explicación del código
#
# `titanic.sex.value_counts().plot(kind="bar", title="Sex Breakdown On Titanic")`
#
# 🔹 **`title="Sex Breakdown On Titanic"`**
# Agrega un **título** a la gráfica.
#
# 📌 ¿Qué muestra?
#
# - Eje X → `male`, `female`
# - Eje Y → cantidad de pasajeros
# - Título → *Sex Breakdown On Titanic*
#
# 👉 **En resumen:**
# Cuenta hombres y mujeres y lo muestra en una gráfica de barras con título.

# %%
titanic.sex.value_counts().plot(kind="bar", title="Sex Breakdown On Titanic")
# Out:
# <Axes: title={'center': 'Sex Breakdown On Titanic'}, xlabel='sex'>

# %% [markdown]
# ### 📊 Explicación del código
# 🔹 **`titanic.sex.value_counts().plot(kind="bar")`**
# - Cuenta cuántos pasajeros hay por sexo
# - Genera una **gráfica de barras**
#
# 🔹 **`plt.title("My Title", loc="right")`**
# Agrega un **título a la gráfica**
# - `"My Title"` → texto del título
# - `loc="right"` → coloca el título en el **lado derecho**
#
# 📌 ¿Qué cambia?
#
# El título no estará centrado (como normalmente), sino alineado a la derecha.
#
# 👉 **En resumen:**
# Crea una gráfica de barras del sexo de los pasajeros y coloca el título alineado a la derecha.

# %%
titanic.sex.value_counts().plot(kind="bar")
plt.title("My Title", loc="right")
# Out:
# Text(1.0, 1.0, 'My Title')

# %% [markdown]
# 🔹 **`ufos["date_time"]`**
# Es una columna de tipo **fecha (datetime)**.
#
# 🔹 **`.dt`**
# Permite acceder a componentes de fecha como año, mes, día, etc.
#
# ---
#
# ### 🔹 Primera línea
#
# `ufos["month"] = ufos["date_time"].dt.month`
#
# - Extrae el **mes** (1 a 12) de cada fecha
# - Lo guarda en una nueva columna llamada **`month`**
#
# ---
#
# ### 🔹 Segunda línea
#
# `ufos["year"] = ufos["date_time"].dt.year`
#
# - Extrae el **año** (ej: 1995, 2001, etc.)
# - Lo guarda en una nueva columna llamada **`year`**
#
# ---
#
# 📌 **Resultado**
#
# El DataFrame ahora tiene dos nuevas columnas:
# - `month` → mes del avistamiento
# - `year` → año del avistamiento
#
# ---
#
# 👉 **En resumen:**
# Extrae el mes y el año de una columna de fechas y los guarda en nuevas columnas.

# %%
ufos["month"] = ufos["date_time"].dt.month
ufos["year"] = ufos["date_time"].dt.year

# %% [markdown]
# ---
#
# ### 🔹 Primera línea
#
# `sightings = ufos.month.value_counts().sort_index()`
#
# - **`ufos.month`** → accede a la columna de meses
# - **`.value_counts()`** → cuenta cuántos avistamientos hay por mes
# - **`.sort_index()`** → ordena los meses de forma ascendente (1 a 12)
#
# 📌 Resultado:
# Una Serie con el número de avistamientos por mes, ordenados correctamente.
#
# ---
#
# ### 🔹 Segunda parte (gráfica)
#
# `sightings.plot(...)`
#
# Genera una **gráfica de barras** con varias configuraciones:
#
# - **`kind="bar"`** → tipo de gráfica
# - **`title="UFO Sightings By Month"`** → título
# - **`xlabel="Month"`** → etiqueta eje X
# - **`ylabel="Num Sightings"`** → etiqueta eje Y
# - **`fontsize="10"`** → tamaño de letra
#
# ---
#
# 📌 ¿Qué muestra la gráfica?
#
# - Eje X → meses (1–12)
# - Eje Y → número de avistamientos
# - Permite ver en qué meses hay más reportes
#
# ---
#
# 👉 **En resumen:**
# Cuenta los avistamientos por mes, los ordena y los muestra en una gráfica de barras bien etiquetada.

# %%
sightings = ufos.month.value_counts().sort_index()
sightings.plot(
    kind="bar", 
    title="UFO Sightings By Month", 
    xlabel="Month",
    ylabel="Num Sightings",
    fontsize="10")
# Out:
# <Axes: title={'center': 'UFO Sightings By Month'}, xlabel='Month', ylabel='Num Sightings'>

# %% [markdown]
# ---
#
# ### 🔹 Cálculo de datos
#
# `sightings = ufos.month.value_counts().sort_index()`
#
# - Cuenta los avistamientos por mes
# - Los ordena de enero (1) a diciembre (12)
#
# ---
#
# ### 🔹 Gráfica base
#
# `sightings.plot(...)`
#
# - Crea una **gráfica de barras**
# - Agrega el título
# - Define tamaño de texto general
#
# ---
#
# ### 🔹 Personalización de ejes
#
# `plt.xlabel("Month", fontsize=24, color="olive")`
#
# - Cambia la etiqueta del eje X
# - Tamaño grande (24)
# - Color **verde oliva**
#
# `plt.ylabel("Num Sightings", fontsize=24)`
#
# - Cambia la etiqueta del eje Y
# - Tamaño grande (24)
#
# ---
#
# 📌 ¿Qué mejora este código?
#
# - Hace la gráfica más **legible**
# - Destaca los nombres de los ejes
# - Mejora la presentación visual
#
# ---
#
# 👉 **En resumen:**
# Genera una gráfica de avistamientos por mes y mejora su apariencia con etiquetas grandes y personalizadas.

# %%
sightings = ufos.month.value_counts().sort_index()
sightings.plot(
    kind="bar", 
    title="UFO Sightings By Month", 
    fontsize="10")
plt.xlabel("Month", fontsize=24, color="olive")
plt.ylabel("Num Sightings", fontsize=24)
# Out:
# Text(0, 0.5, 'Num Sightings')

# %% [markdown]
# ---
#
# ### 🔹 Paso 1: Preparar datos
#
# `sightings = ufos.month.value_counts().sort_index()`
#
# - Cuenta los avistamientos por mes
# - Ordena los meses correctamente (1 a 12)
#
# ---
#
# ### 🔹 Paso 2: Crear la gráfica
#
# `sightings.plot(...)`
#
# - Genera una **gráfica de barras**
# - Agrega título: *UFO Sightings By Month*
# - Define tamaño de fuente general
#
# ---
#
# ### 🔹 Paso 3: Personalizar ejes
#
# `plt.xlabel("Month", fontsize=24, color="olive")`
#
# - Etiqueta eje X
# - Tamaño grande
# - Color personalizado
#
# `plt.ylabel("Num Sightings", fontsize=24)`
#
# - Etiqueta eje Y
# - Tamaño grande
#
# ---
#
# 📌 Resultado final
#
# Una gráfica de barras que:
# - Muestra avistamientos por mes
# - Está ordenada correctamente
# - Tiene etiquetas grandes y más visibles
#
# ---
#
# 👉 **En resumen:**
# Cuenta los avistamientos por mes, los grafica y mejora la presentación con etiquetas personalizadas.

# %%
sightings = ufos.month.value_counts().sort_index()
sightings.plot(
    kind="bar", 
    title="UFO Sightings By Month", 
    fontsize="10")
plt.xlabel("Month", fontsize=24, color="olive")
plt.ylabel("Num Sightings", fontsize=24)
# Out:
# Text(0, 0.5, 'Num Sightings')

# %%
sightings
# Out:
# month
# 1.0      5979
# 2.0      4559
# 3.0      5494
# 4.0      5817
# 5.0      6063
# 6.0      8357
# 7.0     10682
# 8.0      8997
# 9.0      8498
# 10.0     8371
# 11.0     7596
# 12.0     6525
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# ### 🔹 `months_dict`
#
# Es un **diccionario** que convierte:
# - Números de mes → nombres abreviados
#
# Ejemplo:
# - `1 → "Jan"`
# - `2 → "Feb"`
#
# ---
#
# ### 🔹 `sightings.rename(months_dict)`
#
# 🔹 **`rename()`**
# Cambia los valores del índice usando el diccionario.
#
# 📌 En este caso:
# - Los índices (1–12) se reemplazan por nombres de meses

# %%
months_dict = {1: "Jan", 2: "Feb", 3: "Mar", 4: "Apr", 5: "May", 6: "Jun", 7:"Jul", 8: "Aug", 9:"Sep", 10: "Oct", 11: "Nov", 12: "Dec"}
sightings.rename(months_dict)
# Out:
# month
# Jan     5979
# Feb     4559
# Mar     5494
# Apr     5817
# May     6063
# Jun     8357
# Jul    10682
# Aug     8997
# Sep     8498
# Oct     8371
# Nov     7596
# Dec     6525
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# ### 🔹 `sightings.rename(months_dict)`
#
# - Convierte los índices de meses:
#   - `1 → Jan`, `2 → Feb`, etc.
# - Hace que la gráfica sea más **legible**
#
# ---
#
# ### 🔹 `.plot(...)`
#
# - **`kind="bar"`** → gráfica de barras
# - **`title`** → título de la gráfica
# - **`fontsize="20"`** → tamaño de texto más grande
#
# 📌 Ahora el eje X muestra nombres de meses en lugar de números.
#
# ---
#
# ### 🔹 Personalización de ejes
#
# `plt.xlabel("Month", fontsize=24, color="olive")`
# - Etiqueta eje X
# - Tamaño grande
# - Color verde oliva
#
# `plt.ylabel("Num Sightings", fontsize=24)`
# - Etiqueta eje Y
# - Tamaño grande
#
# ---
#
# 📌 Resultado final
#
# Una gráfica que:
# - Muestra avistamientos por mes
# - Usa nombres de meses (Jan, Feb, etc.)
# - Tiene etiquetas grandes y mejor presentación
#
# ---
#
# 👉 **En resumen:**
# Renombra los meses para que sean más claros y genera una gráfica de barras bien estilizada.

# %%
sightings.rename(months_dict).plot(
    kind="bar", 
    title="UFO Sightings By Month", 
    fontsize="20")
plt.xlabel("Month", fontsize=24, color="olive")
plt.ylabel("Num Sightings", fontsize=24)
# Out:
# Text(0, 0.5, 'Num Sightings')

# %%
salaries = pd.read_csv("data/Salaries.csv", low_memory=False)

# %%
salaries["BasePay"] = pd.to_numeric(salaries["BasePay"], errors="coerce").fillna(0)
salaries["OvertimePay"] = pd.to_numeric(salaries["OvertimePay"], errors="coerce").fillna(0)
salaries["OtherPay"] = pd.to_numeric(salaries["OtherPay"], errors="coerce").fillna(0)

# %%
df = salaries[["EmployeeName", "BasePay", "OvertimePay", "OtherPay"]]

# %%
df
# Out:
#              EmployeeName    BasePay  OvertimePay   OtherPay
# 0          NATHANIEL FORD  167411.18         0.00  400184.25
# 1            GARY JIMENEZ  155966.02    245131.88  137811.38
# 2          ALBERT PARDINI  212739.13    106088.18   16452.60
# 3       CHRISTOPHER CHONG   77916.00     56120.71  198306.90
# 4         PATRICK GARDNER  134401.60      9737.00  182234.59
# ...                   ...        ...          ...        ...
# 148649      Roy I Tillery       0.00         0.00       0.00
# 148650       Not provided       0.00         0.00       0.00
# 148651       Not provided       0.00         0.00       0.00
# 148652       Not provided       0.00         0.00       0.00
# 148653          Joe Lopez       0.00         0.00    -618.13
#
# [148654 rows x 4 columns]

# %% [markdown]
# ### 📌 Explicación del código
#
# `df.set_index("EmployeeName", inplace=True)`
#
# 🔹 **`set_index("EmployeeName")`**
# Convierte la columna **`EmployeeName`** en el **índice del DataFrame**.
#
# 🔹 **`inplace=True`**
# Aplica el cambio directamente sobre `df`, sin necesidad de reasignar.
#
# 📌 ¿Qué ocurre?
#
# - La columna `EmployeeName` deja de ser columna normal
# - Pasa a ser el identificador de cada fila (índice)
#
# 🔹 **Antes**
#
# | EmployeeName | Salary |
# |--------------|--------|
# | Juan         | 1000   |
# | Ana          | 1200   |
#
# 🔹 **Después**
#
# | EmployeeName | Salary |
# |--------------|--------|
# | Juan         | 1000   |
# | Ana          | 1200   |
#
# (Pero ahora `EmployeeName` es el índice)
#
# ---
#
# 👉 **En resumen:**
# Convierte `EmployeeName` en el índice del DataFrame y modifica el original.

# %%
df.set_index("EmployeeName", inplace=True)

# %%
df.head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='EmployeeName'>

# %% [markdown]
# ### 📊 Explicación del código
#
# `df.head(10).plot(kind="bar", stacked=True)`
#
# 🔹 **`df.head(10)`**
# Selecciona las **primeras 10 filas** del DataFrame.
#
# 🔹 **`.plot(kind="bar")`**
# Crea una **gráfica de barras**.
#
# 🔹 **`stacked=True`**
# Hace que las barras sean **apiladas**, es decir:
# - Los valores de diferentes columnas se colocan **uno encima de otro** en la misma barra.
#
# 📌 ¿Qué muestra la gráfica?
#
# - Eje X → las primeras 10 filas (índice)
# - Eje Y → valores numéricos
# - Cada barra representa una fila
# - Cada color dentro de la barra representa una columna
#
# 👉 **En resumen:**
# Muestra las primeras 10 filas en una gráfica de barras apiladas para comparar múltiples columnas en cada registro.

# %%
df.head(10).plot(kind="bar", stacked=True)
# Out:
# <Axes: xlabel='EmployeeName'>

# %% [markdown]
# ### 📊 Explicación del código
#
# `df["BasePay"].sort_values(ascending=False).head().plot(kind="bar")`
#
# 🔹 **`df["BasePay"]`**
# Selecciona la columna **BasePay** (salario base).
#
# 🔹 **`.sort_values(ascending=False)`**
# Ordena los valores de mayor a menor.
#
# 🔹 **`.head()`**
# Toma los **primeros 5 valores** (los más altos).
#
# 🔹 **`.plot(kind="bar")`**
# Crea una **gráfica de barras**.
#
# 📌 ¿Qué muestra la gráfica?
#
# - Eje X → los registros con mayor salario (índice, por ejemplo nombres)
# - Eje Y → monto del salario
# - Barras → los **5 salarios más altos**
#
# 👉 **En resumen:**
# Muestra en una gráfica de barras los **5 valores más altos de salario base**.

# %%
df["BasePay"].sort_values(ascending=False).head().plot(kind="bar")
# Out:
# <Axes: xlabel='EmployeeName'>

# %% [markdown]
# ### 📊 Explicación del código
#
# `df["BasePay"].sort_values(ascending=False).head().plot.bar(color="red", title="Highest Paid SF Employees")`
#
# 🔹 **`df["BasePay"]`**
# Selecciona la columna de **salario base**.
#
# 🔹 **`.sort_values(ascending=False)`**
# Ordena los salarios de **mayor a menor**.
#
# 🔹 **`.head()`**
# Toma los **5 salarios más altos**.
#
# 🔹 **`.plot.bar(...)`**
# Crea una **gráfica de barras** (equivalente a `plot(kind="bar")`).
#
# 🔹 **Parámetros adicionales**:
# - **`color="red"`** → barras en color rojo
# - **`title="Highest Paid SF Employees"`** → título de la gráfica
#
# 📌 ¿Qué muestra?
#
# - Eje X → empleados con mayor salario
# - Eje Y → salario base
# - Barras → top 5 salarios más altos
#
# 👉 **En resumen:**
# Muestra los **5 empleados mejor pagados** en una gráfica de barras rojas con título.

# %%
df["BasePay"].sort_values(ascending=False).head().plot.bar(color="red", title="Highest Paid SF Employees")
# Out:
# <Axes: title={'center': 'Highest Paid SF Employees'}, xlabel='EmployeeName'>

# %% [markdown]
# ### 📊 Explicación del código
#
# `df["BasePay"].sort_values(ascending=False).head().plot.barh(color="red", title="Highest Paid SF Employees")`
#
# 🔹 **`df["BasePay"]`**
# Selecciona la columna de **salario base**.
#
# 🔹 **`.sort_values(ascending=False)`**
# Ordena los salarios de **mayor a menor**.
#
# 🔹 **`.head()`**
# Toma los **5 valores más altos**.
#
# 🔹 **`.plot.barh(...)`**
# Crea una **gráfica de barras horizontales**.
#
# 🔹 **Parámetros adicionales**:
# - **`color="red"`** → barras en color rojo
# - **`title="Highest Paid SF Employees"`** → título de la gráfica
#
# 📌 ¿Qué muestra la gráfica?
#
# - Eje Y → empleados (índice)
# - Eje X → salario base
# - Barras horizontales → top 5 salarios más altos
#
# 👉 **En resumen:**
# Muestra los **5 empleados con mayor salario base** en una gráfica de barras horizontales rojas.

# %%
df["BasePay"].sort_values(ascending=False).head().plot.barh(color="red", title="Highest Paid SF Employees")
# Out:
# <Axes: title={'center': 'Highest Paid SF Employees'}, ylabel='EmployeeName'>

# %% [markdown]
# ### 📊 Explicación del código
#
# `df.sort_values("OvertimePay", ascending=False).head().plot(kind="barh", stacked=True)`
#
# 🔹 **`df.sort_values("OvertimePay", ascending=False)`**
# Ordena el DataFrame según la columna **`OvertimePay`** de mayor a menor.
#
# 🔹 **`.head()`**
# Selecciona las **primeras 5 filas**, es decir, los empleados con mayor pago por horas extra.
#
# 🔹 **`.plot(kind="barh")`**
# Crea una **gráfica de barras horizontales**.
#
# 🔹 **`stacked=True`**
# Hace que las barras sean **apiladas**, mostrando varias columnas (por ejemplo: BasePay, OvertimePay, OtherPay) en una sola barra.
#
# 📌 ¿Qué muestra la gráfica?
#
# - Eje Y → empleados (índice)
# - Eje X → valores de pago
# - Cada barra → un empleado
# - Segmentos de la barra → distintos tipos de pago
#
# 👉 **En resumen:**
# Muestra los empleados con mayor pago por horas extra en una gráfica de barras horizontales apiladas, comparando sus diferentes ingresos.

# %%
df.sort_values("OvertimePay", ascending=False).head().plot(kind="barh", stacked=True)
# Out:
# <Axes: ylabel='EmployeeName'>

# %% [markdown]
# ---
#
# ### 🔹 Ordenar y seleccionar datos
#
# `df.sort_values("OvertimePay", ascending=False).head()`
#
# - Ordena por **OvertimePay** de mayor a menor
# - Toma los **5 empleados con más pago por horas extra**
#
# ---
#
# ### 🔹 Gráfica
#
# `.plot.barh(stacked=True)`
#
# - Crea una **gráfica de barras horizontales**
# - **`stacked=True`** → muestra múltiples columnas (pagos) apiladas en cada barra
#
# ---
#
# ### 🔹 Etiqueta del eje X
#
# `plt.xlabel("Dollars")`
#
# - Cambia el nombre del eje X a **"Dollars"**
# - Indica que los valores están en dinero
#
# ---
#
# 📌 ¿Qué muestra la gráfica?
#
# - Eje Y → empleados
# - Eje X → cantidad de dinero
# - Barras → total de pagos (desglosados por tipo)
#
# ---
#
# 👉 **En resumen:**
# Grafica los empleados con mayor pago por horas extra en barras horizontales apiladas y etiqueta el eje X como dólares.

# %%
df.sort_values("OvertimePay", ascending=False).head().plot.barh(stacked=True)
plt.xlabel("Dollars")
# Out:
# Text(0.5, 0, 'Dollars')

# %% [markdown]
# 📉 **Histograma**
#
# Un histograma nos ayuda a ver la distribución de una variable numérica.

# %% [markdown]
# ### 📊 Explicación del código
#
# `df["BasePay"].plot(kind="hist", bins=200, color="purple")`
#
# 🔹 **`df["BasePay"]`**
# Selecciona la columna de **salario base**.
#
# 🔹 **`.plot(kind="hist")`**
# Crea un **histograma**, que muestra la distribución de los datos.
#
# 🔹 **`bins=200`**
# Divide los datos en **200 intervalos (barras)**.
# Más bins → mayor detalle en la distribución.
#
# 🔹 **`color="purple"`**
# Define el color de las barras como **morado**.
#
# 📌 ¿Qué muestra la gráfica?
#
# - Eje X → rangos de salario
# - Eje Y → cantidad de empleados en cada rango
# - Permite ver cómo se distribuyen los salarios
#
# 👉 **En resumen:**
# Muestra la distribución de los salarios base en un histograma detallado de color morado.

# %%
df["BasePay"].plot(kind="hist", bins=200, color="purple")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### 📊 Explicación del código
#
# `df.plot(kind="hist", bins=100)`
#
# 🔹 **`df.plot(kind="hist")`**
# Crea un **histograma** usando **todas las columnas numéricas** del DataFrame.
#
# 🔹 **`bins=100`**
# Divide los datos en **100 intervalos (barras)**.
#
# 📌 ¿Qué hace en conjunto?
#
# - Toma todas las columnas numéricas
# - Genera histogramas para cada una
# - Permite ver la **distribución de los datos**
#
# 🔹 **Resultado**
#
# - Eje X → rangos de valores
# - Eje Y → frecuencia (cuántos datos caen en cada rango)
# - Puede mostrar varias distribuciones superpuestas
#
# 👉 **En resumen:**
# Genera histogramas de todas las columnas numéricas para analizar su distribución.

# %%
df.plot(kind="hist", bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### 📊 Explicación del código
#
# `df.plot.hist(title="SF Salaries")`
#
# 🔹 **`df.plot.hist()`**
# Crea un **histograma** con todas las columnas numéricas del DataFrame.
#
# 🔹 **`title="SF Salaries"`**
# Agrega un **título** a la gráfica.
#
# 📌 ¿Qué muestra?
#
# - Eje X → rangos de valores (salarios u otras variables numéricas)
# - Eje Y → frecuencia
# - Permite ver la **distribución de los datos**
#
# 👉 **En resumen:**
# Genera un histograma de los datos numéricos del DataFrame con el título "SF Salaries".

# %%
df.plot.hist(title="SF Salaries")
# Out:
# <Axes: title={'center': 'SF Salaries'}, ylabel='Frequency'>

# %% [markdown]
# ### 📊 Explicación del código
#
# `df.hist()`
#
# 🔹 **`df.hist()`**
# Genera automáticamente **un histograma para cada columna numérica** del DataFrame.
#
# 📌 ¿Qué hace?
#
# - Toma todas las columnas numéricas
# - Crea una gráfica separada para cada una
# - Las muestra en una cuadrícula
#
# 🔹 **Resultado**
#
# - Varias gráficas (subplots)
# - Cada una muestra la **distribución** de una columna
# - Eje X → valores
# - Eje Y → frecuencia
#
# 📌 Ventaja
# Permite analizar rápidamente cómo se distribuyen múltiples variables al mismo tiempo.
#
# 👉 **En resumen:**
# Crea histogramas individuales para cada columna numérica del DataFrame.

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'BasePay'}>,
#         <Axes: title={'center': 'OvertimePay'}>],
#        [<Axes: title={'center': 'OtherPay'}>, <Axes: >]], dtype=object)

# %% [markdown]
# ## Box Plots

# %% [markdown]
# 📦 **Diagrama de caja (boxplot)**
#
# Útil para ver la mediana, cuartiles y posibles valores atípicos de una variable numérica.

# %%
df.plot(kind="box")
# Out:
# <Axes: >

# %% [markdown]
# ### 📊 Explicación del código
#
# `df.boxplot()`
#
# 🔹 **`df.boxplot()`**
# Crea un **diagrama de caja (boxplot)** para cada columna numérica del DataFrame.
#
# ---
#
# ### 📌 ¿Qué muestra un boxplot?
#
# Para cada columna:
#
# - 📦 **Caja** → representa el rango intercuartil (Q1 a Q3)
# - ➖ **Línea dentro de la caja** → la **mediana**
# - 📏 **Bigotes (whiskers)** → valores mínimos y máximos (sin outliers)
# - ⚠️ **Puntos fuera** → **valores atípicos (outliers)**
#
# ---
#
# ### 🔹 ¿Qué hace en conjunto?
#
# - Analiza la **distribución de los datos**
# - Permite detectar:
#   - dispersión
#   - simetría
#   - valores extremos
#
# ---
#
# 📌 **Resultado**
#
# - Una gráfica con varias cajas (una por cada columna numérica)
#
# ---
#
# 👉 **En resumen:**
# Muestra la distribución de las columnas numéricas usando diagramas de caja, útiles para detectar outliers y comparar datos.

# %%
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### 📊 Explicación del código
#
# `houses.bedrooms.plot(kind="box", showfliers=False)`
#
# 🔹 **`houses.bedrooms`**
# Selecciona la columna **`bedrooms`** (número de habitaciones).
#
# 🔹 **`.plot(kind="box")`**
# Crea un **diagrama de caja (boxplot)** para esa columna.
#
# 🔹 **`showfliers=False`**
# Oculta los **valores atípicos (outliers)** en la gráfica.
#
# ---
#
# ### 📌 ¿Qué muestra?
#
# - 📦 Caja → rango intercuartil (Q1 a Q3)
# - ➖ Línea → mediana
# - 📏 Bigotes → valores mínimo y máximo (sin outliers visibles)
#
# ---
#
# 📌 ¿Para qué sirve esto?
#
# - Analizar la distribución del número de habitaciones
# - Evitar que los outliers distorsionen la visualización
#
# ---
#
# 👉 **En resumen:**
# Muestra un boxplot de habitaciones sin incluir los valores atípicos.

# %%
houses.bedrooms.plot(kind="box", showfliers=False)
# Out:
# <Axes: >

# %% [markdown]
# ### 📊 Explicación del código
#
# `houses[["bedrooms", "bathrooms"]].boxplot(showfliers=False)`
#
# 🔹 **`houses[["bedrooms", "bathrooms"]]`**
# Selecciona dos columnas del DataFrame:
# - `bedrooms` (habitaciones)
# - `bathrooms` (baños)
#
# 🔹 **`.boxplot()`**
# Genera un **diagrama de caja para cada columna**.
#
# 🔹 **`showfliers=False`**
# Oculta los **valores atípicos (outliers)**.
#
# ---
#
# ### 📌 ¿Qué muestra la gráfica?
#
# - Dos boxplots:
#   - Uno para habitaciones
#   - Otro para baños
#
# Cada uno muestra:
# - 📦 rango intercuartil
# - ➖ mediana
# - 📏 dispersión de datos
#
# ---
#
# 📌 ¿Para qué sirve?
#
# Permite **comparar la distribución** entre:
# - número de habitaciones
# - número de baños
#
# sin que los outliers afecten la visualización.
#
# ---
#
# 👉 **En resumen:**
# Compara la distribución de habitaciones y baños con boxplots sin mostrar valores atípicos.

# %%
houses[["bedrooms", "bathrooms"]].boxplot(showfliers=False)
# Out:
# <Axes: >

# %% [markdown]
# ## Line Plots

# %% [markdown]
# 📈 **Gráfico de líneas**
#
# Ideal para mostrar tendencias a lo largo del tiempo.

# %% [markdown]
# ### 📊 Explicación del código
#
# `ufos.year.value_counts().sort_index().plot(kind="line", color="olive", linestyle=":")`
#
# ---
#
# ### 🔹 Conteo de datos
#
# `ufos.year.value_counts()`
#
# - Cuenta cuántos avistamientos hay por **año**
#
# 🔹 **`.sort_index()`**
# - Ordena los años de forma ascendente (cronológicamente)
#
# ---
#
# ### 🔹 Gráfica
#
# `.plot(kind="line", ...)`
#
# - Crea una **gráfica de línea**
#
# 🔹 Parámetros:
# - **`color="olive"`** → línea color verde oliva
# - **`linestyle=":"`** → línea punteada
#
# ---
#
# ### 📌 ¿Qué muestra?
#
# - Eje X → años
# - Eje Y → número de avistamientos
# - Línea → evolución de avistamientos a lo largo del tiempo
#
# ---
#
# 👉 **En resumen:**
# Muestra cómo cambian los avistamientos de ovnis por año en una gráfica de línea estilizada.

# %%
ufos.year.value_counts().sort_index().plot(kind="line", color="olive", linestyle=":")
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ### 📊 Explicación del código
#
# `houses.plot.line(x="bedrooms", y="price")`
#
# 🔹 **`houses.plot.line()`**
# Crea una **gráfica de línea** a partir del DataFrame.
#
# 🔹 **`x="bedrooms"`**
# Define que el eje X será la columna **`bedrooms`** (número de habitaciones).
#
# 🔹 **`y="price"`**
# Define que el eje Y será la columna **`price`** (precio de la casa).
#
# ---
#
# ### 📌 ¿Qué muestra?
#
# - Eje X → número de habitaciones
# - Eje Y → precio
# - Línea → relación entre habitaciones y precio
#
# ---
#
# 📌 Interpretación
#
# Permite observar cómo cambia el **precio** conforme aumenta el número de **habitaciones**.
#
# ⚠️ Nota:
# Si los datos no están ordenados por `bedrooms`, la línea puede verse irregular.
#
# ---
#
# 👉 **En resumen:**
# Grafica la relación entre número de habitaciones y precio usando una línea.

# %%
houses.plot.line(x="bedrooms", y="price")
# Out:
# <Axes: xlabel='bedrooms'>

# %% [markdown]
# ## Scatter Plots

# %% [markdown]
# ### 📊 Explicación del código
#
# `houses.plot.scatter(x="bedrooms", y="bathrooms")`
#
# 🔹 **`houses.plot.scatter()`**
# Crea una **gráfica de dispersión (scatter plot)**.
#
# 🔹 **`x="bedrooms"`**
# Define el eje X como la columna **`bedrooms`** (número de habitaciones).
#
# 🔹 **`y="bathrooms"`**
# Define el eje Y como la columna **`bathrooms`** (número de baños).
#
# ---
#
# ### 📌 ¿Qué muestra?
#
# - Cada punto → una casa
# - Eje X → número de habitaciones
# - Eje Y → número de baños
#
# ---
#
# ### 📌 ¿Para qué sirve?
#
# - Analizar la **relación** entre habitaciones y baños
# - Detectar patrones o tendencias (por ejemplo: más habitaciones → más baños)
#
# ---
#
# 👉 **En resumen:**
# Muestra cómo se relacionan el número de habitaciones y baños mediante una gráfica de puntos.

# %%
houses.plot.scatter(x="bedrooms", y="bathrooms")
# Out:
# <Axes: xlabel='bedrooms', ylabel='bathrooms'>

# %% [markdown]
# ### 📊 Explicación del código
#
# `houses.plot.scatter(x="bedrooms", y="bathrooms", marker="X")`
#
# 🔹 **`houses.plot.scatter()`**
# Crea una **gráfica de dispersión**.
#
# 🔹 **`x="bedrooms"`**
# Eje X → número de habitaciones.
#
# 🔹 **`y="bathrooms"`**
# Eje Y → número de baños.
#
# 🔹 **`marker="X"`**
# Cambia la forma de los puntos a una **X** en lugar del punto por defecto.
#
# ---
#
# ### 📌 ¿Qué muestra?
#
# - Cada **X** representa una casa
# - Relación entre habitaciones y baños
#
# ---
#
# ### 📌 ¿Qué cambia con `marker="X"`?
#
# - Mejora la visibilidad de los puntos
# - Hace la gráfica más distintiva
#
# ---
#
# 👉 **En resumen:**
# Es una gráfica de dispersión entre habitaciones y baños, usando marcadores en forma de **X**.

# %%
houses.plot.scatter(x="bedrooms", y="bathrooms", marker="X")
# Out:
# <Axes: xlabel='bedrooms', ylabel='bathrooms'>

# %% [markdown]
# # Multiple Plots On The Same Axes

# %% [markdown]
# ---
#
# ### 🔹 Filtrar por estado
#
# - `ufos[ufos["state"] == "CA"]`
# - `ufos[ufos["state"] == "TX"]`
#
# - Selecciona los registros de:
#   - California (CA)
#   - Texas (TX)
#
# ---
#
# ### 🔹 Conteo por año
#
# `.year.value_counts().sort_index()`
#
# - Cuenta avistamientos por año
# - Los ordena cronológicamente
#
# ---
#
# ### 🔹 Graficar
#
# - `.plot(label="CA")`
# - `.plot(label="TX")`
#
# - Crea dos **líneas en la misma gráfica**
# - Cada una representa un estado
# - `label` sirve para la leyenda
#
# ---
#
# ### 🔹 Personalización
#
# - **`plt.legend(loc="upper left")`** → muestra la leyenda
# - **`plt.title(...)`** → título de la gráfica
# - **`plt.xlabel("Year")`** → etiqueta eje X
#
# ---
#
# ### 📌 ¿Qué muestra?
#
# - Eje X → años
# - Eje Y → número de avistamientos
# - Dos líneas → comparación entre CA y TX
#
# ---
#
# 👉 **En resumen:**
# Compara los avistamientos de ovnis por año entre California y Texas en una gráfica de líneas.

# %%
ufos[ufos["state"] == "CA"].year.value_counts().sort_index().plot(label="CA")
ufos[ufos["state"] == "TX"].year.value_counts().sort_index().plot(label="TX")
plt.legend(loc="upper left")
plt.title("UFO Sighting By State")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# # UFOS Plotting Challenge!

# %% [markdown]
# ### 📊 Explicación del código
#
# `ufos["shape"].value_counts()`
#
# 🔹 **`ufos["shape"]`**
# Selecciona la columna **`shape`**, que indica la forma del ovni (ej: circle, triangle, light, etc.).
#
# 🔹 **`.value_counts()`**
# Cuenta cuántas veces aparece cada valor en esa columna.
#
# ---
#
# ### 📌 ¿Qué hace?
#
# - Cuenta la frecuencia de cada tipo de forma
# - Ordena los resultados de mayor a menor
#
# ---
#
# ### 🔹 Resultado
#
# Una **Serie** donde:
# - Índice → tipo de forma
# - Valores → número de apariciones
#
# Ejemplo:
#
#
# - light 1000
# - triangle 800
# - circle 750
#
#
# ---
#
# 👉 **En resumen:**
# Cuenta cuántas veces aparece cada tipo de forma de ovni en el dataset.

# %%
ufos["shape"].value_counts()
# Out:
# shape
# light        18230
# circle       10130
# triangle      7910
# fireball      7095
# unknown       6182
# sphere        6065
# other         5749
# disk          4522
# oval          3857
# formation     2842
# changing      2112
# cigar         1990
# flash         1675
# rectangle     1597
# cylinder      1374
# diamond       1273
# chevron        953
# teardrop       767
# egg            666
# cone           349
# cross          289
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# ### 🔹 Filtrar por forma
#
# Se filtran los datos por diferentes valores de la columna **`shape`**:
# - `"formation"`
# - `"oval"`
# - `"disk"`
#
# (Las otras líneas están comentadas, por lo que no se ejecutan)
#
# ---
#
# ### 🔹 Conteo por año
#
# `.year.value_counts().sort_index()`
#
# - Cuenta avistamientos por año
# - Los ordena cronológicamente
#
# ---
#
# ### 🔹 Graficar
#
# `.plot(label="...")`
#
# - Dibuja una **línea por cada forma**
# - `label` identifica cada línea en la leyenda
#
# ---
#
# ### 🔹 Personalización
#
# - **`plt.xlim(2000,2020)`** → limita el eje X entre 2000 y 2020
# - **`plt.legend(loc="upper left")`** → muestra leyenda
# - **`plt.title(...)`** → título
# - **`plt.xlabel("Year")`** → etiqueta eje X
#
# ---
#
# ### 📌 ¿Qué muestra?
#
# - Eje X → años (2000–2020)
# - Eje Y → número de avistamientos
# - Líneas → diferentes formas de ovnis
#
# ---
#
# 👉 **En resumen:**
# Compara la evolución de avistamientos por año para distintas formas de ovnis en una gráfica de líneas.

# %%
ufos[ufos["shape"] == "formation"].year.value_counts().sort_index().plot(label="formation")
ufos[ufos["shape"] == "oval"].year.value_counts().sort_index().plot(label="oval")
# ufos[ufos["shape"] == "light"].year.value_counts().sort_index().plot(label="light")
# ufos[ufos["shape"] == "circle"].year.value_counts().sort_index().plot(label="circle")
# ufos[ufos["shape"] == "fireball"].year.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"] == "disk"].year.value_counts().sort_index().plot(label="disk")
plt.xlim(2000,2020)
plt.legend(loc="upper left")
plt.title("UFO Sighting By State")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
ufos[ufos["shape"] == "formation"].year.value_counts().sort_index().plot(label="formation")
ufos[ufos["shape"] == "oval"].year.value_counts().sort_index().plot(label="oval")
ufos[ufos["shape"] == "light"].year.value_counts().sort_index().plot(label="light")
# ufos[ufos["shape"] == "circle"].year.value_counts().sort_index().plot(label="circle")
ufos[ufos["shape"] == "fireball"].year.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"] == "disk"].year.value_counts().sort_index().plot(label="disk")
# plt.xlim(2000,2020)
plt.legend(loc="upper left")
plt.title("UFO Sighting By State")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
ufos[ufos["shape"] == "formation"].year.value_counts().sort_index().plot(label="formation")
ufos[ufos["shape"] == "oval"].year.value_counts().sort_index().plot(label="oval")
ufos[ufos["shape"] == "light"].year.value_counts().sort_index().plot(label="light")
# ufos[ufos["shape"] == "circle"].year.value_counts().sort_index().plot(label="circle")
ufos[ufos["shape"] == "fireball"].year.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"] == "disk"].year.value_counts().sort_index().plot(label="disk")
# plt.xlim(2000,2020)
plt.legend(loc="upper left")
plt.title("UFO Sighting By State")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
ufos[ufos["shape"] == "formation"].month.value_counts().sort_index().plot(label="formation")
ufos[ufos["shape"] == "fireball"].month.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"] == "sphere"].month.value_counts().sort_index().plot(label="sphere")
ufos[ufos["shape"] == "oval"].month.value_counts().sort_index().plot(label="oval")
plt.legend()

# %%
ufos["shape"].value_counts()
# Out:
# shape
# light        18230
# circle       10130
# triangle      7910
# fireball      7095
# unknown       6182
# sphere        6065
# other         5749
# disk          4522
# oval          3857
# formation     2842
# changing      2112
# cigar         1990
# flash         1675
# rectangle     1597
# cylinder      1374
# diamond       1273
# chevron        953
# teardrop       767
# egg            666
# cone           349
# cross          289
# Name: count, dtype: int64

# %%
ufos[ufos["shape"] == "formation"].date_time.dt.date.value_counts().sort_index().plot(label="formation")
ufos[ufos["shape"] != "formation"].date_time.dt.date.value_counts().sort_index().plot(label="all")
# Out:
# <Axes: xlabel='date_time'>

# %%
ufos[ufos["shape"] == "formation"].date_time.dt.date.value_counts().sort_index().plot()
# ufos[ufos["shape"] == "cigar"].date_time.dt.date.value_counts().sort_index().plot()
# ufos[ufos["shape"] == "fireball"].date_time.dt.date.value_counts().sort_index().plot()
# ufos[ufos["shape"] == "sphere"].date_time.dt.date.value_counts().sort_index().plot()
# ufos[ufos["shape"] == "sphere"].date_time.dt.date.value_counts().sort_index().plot()
ufos[ufos["shape"] != "formation"].date_time.dt.date.value_counts().sort_index().plot()
plt.xlim("2019-04-01", "2019-12-31")
# Out:
# (np.float64(17987.0), np.float64(18261.0))

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
ufos[ufos["shape"] == "circle"].date_time.dt.date.value_counts().sort_index().plot(label="circle")
ufos[ufos["shape"] == "light"].date_time.dt.date.value_counts().sort_index().plot(label="light")
ufos[ufos["shape"] == "triangle"].date_time.dt.date.value_counts().sort_index().plot(label="triangle")
ufos[ufos["shape"] == "fireball"].date_time.dt.date.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"] == "cigar"].date_time.dt.date.value_counts().sort_index().plot(label="cigar")
plt.legend()

# %%
ufos[ufos["shape"] == "circle"].year.value_counts().sort_index().plot(label="circle")
# ufos[ufos["shape"] == "light"].year.value_counts().sort_index().plot(label="light")
ufos[ufos["shape"] == "triangle"].year.value_counts().sort_index().plot(label="triangle")
ufos[ufos["shape"] == "fireball"].year.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"] == "cigar"].year.value_counts().sort_index().plot(label="cigar")
ufos[ufos["shape"] == "formation"].year.value_counts().sort_index().plot(label="formation")
plt.legend()
plt.xlim(2010,2018)
# Out:
# (2010.0, 2018.0)

# %%
plt.figure(figsize=(10,8))
ufos[ufos["shape"] == "circle"].year.value_counts().sort_index().plot(label="circle")
ufos[ufos["shape"] == "light"].year.value_counts().sort_index().plot(label="light")
ufos[ufos["shape"] == "triangle"].year.value_counts().sort_index().plot(label="triangle")
ufos[ufos["shape"] == "fireball"].year.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"] == "formation"].year.value_counts().sort_index().plot(label="formation")
plt.legend()
plt.xlim(2000,2018)
plt.title("UFO Sightings By Shape (2000-2018)")
# Out:
# Text(0.5, 1.0, 'UFO Sightings By Shape (2000-2018)')

# %%
ufos[ufos["shape"] == "light"].year.value_counts().sort_index().plot(label="light", figsize=(10,8), title="UFO Sightings By Shape")
ufos[ufos["shape"] == "fireball"].year.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"] == "circle"].year.value_counts().sort_index().plot(label="circle")
ufos[ufos["shape"] == "triangle"].year.value_counts().sort_index().plot(label="triangle")
ufos[ufos["shape"] == "formation"].year.value_counts().sort_index().plot(label="formation")

plt.xlim(2000, 2019)
plt.legend()

# %% [markdown]
# ## Subplots

# %% [markdown]
# 📉 **Histograma**
#
# Un histograma nos ayuda a ver la distribución de una variable numérica.

# %%
df.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ---
#
# ### 🔹 `df.plot(kind="hist", ...)`
#
# Crea histogramas para las columnas numéricas del DataFrame.
#
# 🔹 Parámetros:
#
# - **`subplots=True`**
#   Genera **un histograma por cada columna** en gráficos separados.
#
# - **`sharex=False`**
#   Cada gráfico tiene su **propio eje X** (no se comparten escalas).
#
# - **`figsize=(5,5)`**
#   Define el tamaño total de la figura.
#
# ---
#
# ### 🔹 `plt.tight_layout()`
#
# - Ajusta automáticamente los espacios entre gráficos
# - Evita que se encimen etiquetas, títulos o ejes
#
# ---
#
# ### 📌 ¿Qué muestra?
#
# - Varios histogramas (uno por columna)
# - Cada uno muestra la **distribución de datos** de una variable
#
# ---
#
# 👉 **En resumen:**
# Genera histogramas separados para cada columna y ajusta el diseño para que se vean correctamente.

# %%
df.plot(kind="hist", subplots=True, sharex=False, figsize=(5,5))
plt.tight_layout()

# %% [markdown]
# ---
#
# ### 🔹 Crear histogramas
#
# `df.plot(kind="hist", ...)`
#
# - Genera histogramas para columnas numéricas
#
# 🔹 Parámetros importantes:
#
# - **`subplots=True`** → un gráfico por columna
# - **`layout=(1,3)`** → organiza los gráficos en **1 fila y 3 columnas**
# - **`figsize=(10,3)`** → tamaño de la figura
# - **`bins=30`** → número de intervalos
#
# ---
#
# ### 🔹 Ajustar layout
#
# `plt.tight_layout()`
#
# - Evita que los gráficos se encimen
#
# ---
#
# ### 🔹 `axs`
#
# - Es una matriz de ejes (subplots)
# - Se accede como: `axs[fila][columna]`
#
# ---
#
# ### 🔹 Personalización de subplots
#
# - `axs[0][2].set_xlim(0,20000)`
#   → cambia el rango del eje X del **tercer gráfico**
#
# - `axs[0][1].set_title("Middle")`
#   → título del segundo gráfico
#
# - `axs[0][0].set_title("First")`
#   → título del primero
#
# - `axs[0][2].set_title("Third")`
#   → título del tercero
#
# ---
#
# ### 📌 Resultado
#
# - 3 histogramas en una fila
# - Cada uno con título personalizado
# - Uno con rango de valores ajustado
#
# ---
#
# 👉 **En resumen:**
# Crea varios histogramas organizados en una fila y personaliza cada uno individualmente.

# %%
axs = df.plot(kind="hist", subplots=True, sharex=False, layout=(1,3), figsize=(10,3), bins=30)
plt.tight_layout()
axs[0][2].set_xlim(0,20000)
axs[0][1].set_title("Middle")
axs[0][0].set_title("First")
axs[0][2].set_title("Third")
# Out:
# Text(0.5, 1.0, 'Third')

# %%
ufos.year.value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>

# %%
ufos.month.value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ## Manual Subplots

# %%
fig, axs = plt.subplots(1,2)
ufos.year.value_counts().sort_index().plot(ax=axs[0])
axs[0].set_title("Sightings By Year")
ufos.month.value_counts().sort_index().plot(kind="bar", ax=axs[1])
axs[1].set_title("Sightings By Month")
# Out:
# Text(0.5, 1.0, 'Sightings By Month')

# %%
months = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 
          7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
fig, axs = plt.subplots(2, 3, figsize=(14, 8))
fig.suptitle("UFO sightings by month", fontsize=14)
fig.tight_layout(pad=2)
ufos[ufos.year == 2014].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[0][0], title="2014")
ufos[ufos.year == 2015].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[0][1], title="2015")
ufos[ufos.year == 2016].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[0][2], title="2016")
ufos[ufos.year == 2017].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[1][0], title="2017")
ufos[ufos.year == 2018].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[1][1], title="2018")
ufos[ufos.year == 2019].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[1][2], title="2019")
plt.tight_layout()

# %% [markdown]
# ## Savefig()

# %%
ufos[ufos["shape"] == "light"].year.value_counts().sort_index().plot(label="light", figsize=(10,8), title="UFO Sightings By Shape")
ufos[ufos["shape"] == "fireball"].year.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"] == "circle"].year.value_counts().sort_index().plot(label="circle")
ufos[ufos["shape"] == "triangle"].year.value_counts().sort_index().plot(label="triangle")
ufos[ufos["shape"] == "formation"].year.value_counts().sort_index().plot(label="formation")

plt.xlim(2000, 2019)
plt.legend()
plt.savefig("UFO_Shapes")

# %%
months = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 
          7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
fig, axs = plt.subplots(2, 3, figsize=(14, 8))
fig.suptitle("UFO sightings by month", fontsize=14)
fig.tight_layout(pad=2)
ufos[ufos.year == 2014].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[0][0], title="2014")
ufos[ufos.year == 2015].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[0][1], title="2015")
ufos[ufos.year == 2016].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[0][2], title="2016")
ufos[ufos.year == 2017].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[1][0], title="2017")
ufos[ufos.year == 2018].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[1][1], title="2018")
ufos[ufos.year == 2019].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[1][2], title="2019")
plt.tight_layout()
plt.savefig("UFO_By_Month")
