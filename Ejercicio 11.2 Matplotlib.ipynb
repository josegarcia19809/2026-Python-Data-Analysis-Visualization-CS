# %% [markdown]
# # Ejercicio de Matplotlib

# %% [markdown]
# ## Parte 2
#
# Por favor, recrea la gráfica de barras que se muestra abajo.
#
# * La figura debe ser de 8x6.
# * Los dos colores utilizados son `#74b9ff` y `#7ed6df`.
#
# ![Part2.png](attachment:Part2.png)

# %%
# Usa estos datos para generar la gráfica!
resorts = ["Crested Butte", "Aspen", "Telluride", "Wolf Creek"]
snow_last_24 = [29,15,15,23]
snow_next_24 = [16,6,19,30]
